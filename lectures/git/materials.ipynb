# %% [markdown]
# Команди типу ls, cd, echo - це команди Bash, в Anaconda Prompt на Windows будуть інші. Відповідники команд Ви можете знайти у статті у вступному модулі (для анаконди Вам треба третій стовпець).

# %% [markdown]
# Домашнє завдання 3: git
#
#
#
# Дедлайн до цього завдання — останній день курсу. Протягом курсу ви можете його виконати в будь-який зручний час. У цьому завданні є мінімальний обʼєм, і його буде достатньо для зарахування цього завдання, і максимальний обʼєм — який дозволить Вам взяти максимум від цього модуля.
#
#
#
# Завдання:
#
# мінімум: зробити одну звʼязку в терміналі локально git add → git commit → git push origin та додати скриншот термінала та скриншот історії комітів у github. Приклад:
#
#
#
#
# максимум: повторити за мною всі операції з git, які я роблю у лекції. Додати скриншот термінала та скриншот історії комітів у github.
#
# Якщо у Вас в процесі виникнуть якісь питання, їх можна також лишити в цій домашці, або написати в чат.
